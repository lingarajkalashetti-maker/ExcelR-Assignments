# %% [raw]
# Exercise 1: Prime Numbers
# Write a Python program that checks whether a given number is prime or not. A prime number is a natural number greater than 1 that has no positive divisors other than 1 and itself.

# %%
num = int(input("Enter a number: "))
is_prime = True
if num <= 1:
    is_prime = False
else:
    for i in range(2,num):
        if num % i == 0:
            is_prime = False
            break
if is_prime == True:
     print(num, "is a prime number.")
else:
    print(num,"is not a prime number.")
# Out:
# Enter a number:  15
# 15 is not a prime number.

# %% [raw]
# Exercise 2: Product of Random Numbers
#
# Develop a Python program that generates two random numbers and asks the user to enter the product of these numbers. The program should then check if the user's answer is correct and display an appropriate message.

# %%
import random
num1 = random.randint(1,25)
num2 = random.randint(1,15)
right_answer = num1 * num2
print(f"what is {num1} multiplied by {num2}?")
user_answer = int(input("Enter your answer: "))
if user_answer == right_answer:
    print("Correctanswer. well done.")
else:
    print(f"wrong amswer. the correct answer was {right_answer}.")
# Out:
# what is 21 multiplied by 5?
# Enter your answer:  15
# wrong amswer. the correct answer was 105.

# %% [raw]
# Exercise 3: Squares of Even/Odd Numbers
#
# Create a Python script that prints the squares of all even or odd numbers within the range of 100 to 200. Choose either even or odd numbers and document your choice in the code.

# %%
for num in range(100, 200):
  if num % 2 == 0:
     square = num * num
print(num, "squared is",square)
# Out:
# 199 squared is 39204

# %% [raw]
# Exercise 4:
#
# ✅ Problem Statement (Question): Hospital Billing System
#
# A hospital charges its patients based on the following:
#
# · Room charges per day: ₹2,000
#
# · Doctor consultation fee (flat): ₹1,500
#
# · Lab test charges: Based on the number of tests taken. Each test costs ₹300
#
# · Medicine charges: Total cost of medicines provided
#
# · Discount: If the total bill (before discount) exceeds ₹10,000, a 10% discount is applied
#
# Write a Python program to calculate the final bill for a patient who:
#
# · Stayed for 4 days
# · Had 3 lab tests
#
# · Had medicine charges of ₹2,400

# %%
room_charge_per_day = 2000
doctor_fees = 1500
lab_test_charges_for_each_test = 300
days_stayed = int(input("Enter the number of days stayed at the hospital"))
lab_tests_taken = int(input("Enter the number of lab test taken"))
medicine_charges = 2400

total_room_cost = days_stayed * room_charge_per_day
total_test_cost = lab_tests_taken * lab_test_charges_for_each_test

total_bill = total_room_cost * total_test_cost
if total_bill>10000:
    discount = total_bill * 0.10
    final_bill = total_bill - discount
else:
    discount = 0
    final_bill = total_bill

print("Total bill before discount: Rs.",total_bill)
print("Discount applied: Rs.",discount)
print("Final bill to pay: Rs.",final_bill)
# Out:
# Enter the number of days stayed at the hospital 4
# Enter the number of lab test taken 3
# Total bill before discount: Rs. 7200000
# Discount applied: Rs. 720000.0
# Final bill to pay: Rs. 6480000.0
